# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/DataScience/Salary_Dataset_with_Extra_Features.csv.zip')

# %%
df
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %%
df.tail()
# Out:
#        Rating             Company Name                 Job Title  Salary  \
# 22765     4.7         Expert Solutions             Web Developer  200000
# 22766     4.0  Nextgen Innovation Labs             Web Developer  300000
# 22767     4.1                  Fresher  Full Stack Web Developer  192000
# 22768     4.1                Accenture  Full Stack Web Developer  300000
# 22769     3.8          Thomson Reuters   Associate Web Developer  300000
#
#        Salaries Reported   Location Employment Status Job Roles
# 22765                  1  Bangalore         Full Time       Web
# 22766                  1  Bangalore         Full Time       Web
# 22767                 13  Bangalore         Full Time       Web
# 22768                  7  Bangalore         Full Time       Web
# 22769                  7  Bangalore         Full Time       Web

# %%
df.describe()
# Out:
#              Rating        Salary  Salaries Reported
# count  22770.000000  2.277000e+04       22770.000000
# mean       3.918213  6.953872e+05           1.855775
# std        0.519675  8.843990e+05           6.823668
# min        1.000000  2.112000e+03           1.000000
# 25%        3.700000  3.000000e+05           1.000000
# 50%        3.900000  5.000000e+05           1.000000
# 75%        4.200000  9.000000e+05           1.000000
# max        5.000000  9.000000e+07         361.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22770 entries, 0 to 22769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             22770 non-null  float64
#  1   Company Name       22769 non-null  object
#  2   Job Title          22770 non-null  object
#  3   Salary             22770 non-null  int64
#  4   Salaries Reported  22770 non-null  int64
#  5   Location           22770 non-null  object
#  6   Employment Status  22770 non-null  object
#  7   Job Roles          22770 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
df.dropna()
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df.reset_index()
# Out:
#        index  Rating                      Company Name  \
# 0          0     3.8                            Sasken
# 1          1     4.5  Advanced Millennium Technologies
# 2          2     4.0                         Unacademy
# 3          3     3.8                SnapBizz Cloudtech
# 4          4     4.4            Appoids Tech Solutions
# ...      ...     ...                               ...
# 22765  22765     4.7                  Expert Solutions
# 22766  22766     4.0           Nextgen Innovation Labs
# 22767  22767     4.1                           Fresher
# 22768  22768     4.1                         Accenture
# 22769  22769     3.8                   Thomson Reuters
#
#                       Job Title   Salary  Salaries Reported   Location  \
# 0             Android Developer   400000                  3  Bangalore
# 1             Android Developer   400000                  3  Bangalore
# 2             Android Developer  1000000                  3  Bangalore
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                      Rating    Salary  Salaries Reported
# Rating             1.000000  0.025476          -0.011690
# Salary             0.025476  1.000000           0.004481
# Salaries Reported -0.011690  0.004481           1.000000

# %%
df.isna().sum()
# Out:
# Rating               0
# Company Name         1
# Job Title            0
# Salary               0
# Salaries Reported    0
# Location             0
# Employment Status    0
# Job Roles            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Rating               0
# Company Name         0
# Job Title            0
# Salary               0
# Salaries Reported    0
# Location             0
# Employment Status    0
# Job Roles            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21458 entries, 0 to 21457
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              21458 non-null  int64
#  1   Rating             21458 non-null  float64
#  2   Company Name       21458 non-null  object
#  3   Job Title          21458 non-null  object
#  4   Salary             21458 non-null  int64
#  5   Salaries Reported  21458 non-null  int64
#  6   Location           21458 non-null  object
#  7   Employment Status  21458 non-null  object
#  8   Job Roles          21458 non-null  object
#  9   Salary Range       21458 non-null  object
#  10  Location Category  21458 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.8+ MB

# %%
df.reset_index()
# Out:
#        index  Rating                      Company Name  \
# 0          0     3.8                            Sasken
# 1          1     4.5  Advanced Millennium Technologies
# 2          2     4.0                         Unacademy
# 3          3     3.8                SnapBizz Cloudtech
# 4          4     4.4            Appoids Tech Solutions
# ...      ...     ...                               ...
# 22764  22765     4.7                  Expert Solutions
# 22765  22766     4.0           Nextgen Innovation Labs
# 22766  22767     4.1                           Fresher
# 22767  22768     4.1                         Accenture
# 22768  22769     3.8                   Thomson Reuters
#
#                       Job Title   Salary  Salaries Reported   Location  \
# 0             Android Developer   400000                  3  Bangalore
# 1             Android Developer   400000                  3  Bangalore
# 2             Android Developer  1000000                  3  Bangalore
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
obj,num=[],[]
for col in df.columns:
  if df[col].dtype==object:
    obj.append(col)
  else:
    num.append(col)
obj,num
# Out:
# (['Company Name',
#   'Job Title',
#   'Location',
#   'Employment Status',
#   'Job Roles',
#   'Salary Range',
#   'Location Category'],
#  ['index', 'Rating', 'Salary', 'Salaries Reported'])

# %%
for i in num:
  print(f'statistical analysis of column {i}')
  print(f'mean- {df[i].mean()}')
  print(f'median- {df[i].median()}')
  print(f'std- {df[i].std()}')
  print(f'min- {df[i].min()}')
  print(f'max- {df[i].max()}')
  print('--------------------------------')
# Out:
# statistical analysis of column Rating
# mean- 3.9182089683341386
# median- 3.9
# std- 0.519686474762063
# min- 1.0
# max- 5.0
# --------------------------------
# statistical analysis of column Salary
# mean- 695365.5760024595
# median- 500000.0
# std- 884412.4095740649
# min- 2112
# max- 90000000
# --------------------------------
# statistical analysis of column Salaries Reported
# mean- 1.855812727831701
# median- 1.0
# std- 6.823815673596557
# min- 1
# max- 361
# --------------------------------

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df['Salary'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f5923595240>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f5923595780>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f5923594f70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f5923595cc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f5923595f60>],
#  'means': []}

# %%
q1=df['Salary'].quantile(.25)
q3=df['Salary'].quantile(.75)
iqr=q3-q1
min_range=q1-iqr*1.5
maxrange=q3+iqr*1.5

# %%
df=df[(df['Salary']>min_range)&(df['Salary']<maxrange)]
df.reset_index(inplace=True)

# %%
def categorize_salary(salary):
    if salary < 400000:
        return 'Low'
    elif salary <= 800000:
        return 'Medium'
    else:
        return 'High'

# %%
df['Salary Range'] = df['Salary'].apply(categorize_salary)
# Out:
# <ipython-input-36-ea1df4debca8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salary Range'] = df['Salary'].apply(categorize_salary)

# %%
def location_category(location):
    metro_cities = ['Bangalore', 'Mumbai', 'Delhi', 'Hyderabad', 'Chennai', 'Pune', 'Kolkata']

    if location in metro_cities :
      return 'Metropolitan'

    else:
      return 'Non-Metropolitan'

# %%
df['Location Category'] = df['Location'].apply(location_category)
# Out:
# <ipython-input-40-a57e90ccb466>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Location Category'] = df['Location'].apply(location_category)

# %%
df
# Out:
#        index  Rating                      Company Name  \
# 0          0     3.8                            Sasken
# 1          1     4.5  Advanced Millennium Technologies
# 2          2     4.0                         Unacademy
# 3          3     3.8                SnapBizz Cloudtech
# 4          4     4.4            Appoids Tech Solutions
# ...      ...     ...                               ...
# 21453  22765     4.7                  Expert Solutions
# 21454  22766     4.0           Nextgen Innovation Labs
# 21455  22767     4.1                           Fresher
# 21456  22768     4.1                         Accenture
# 21457  22769     3.8                   Thomson Reuters
#
#                       Job Title   Salary  Salaries Reported   Location  \
# 0             Android Developer   400000                  3  Bangalore
# 1             Android Developer   400000                  3  Bangalore
# 2             Android Developer  1000000                  3  Bangalore
# ...

# %%
plt.boxplot(df['Salary'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f592345d840>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f592345d300>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f592345dae0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f592345cd60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f592345cac0>],
#  'means': []}

# %%
for i in num:
  plt.hist(df[i])
  plt.title(f'hist plot of {i}')
  plt.xlabel(f'{i}')
  plt.ylabel('frequency')
  plt.show()

# %%
import seaborn as sns

# %%
cor=df.corr(numeric_only=True)
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %%
for i in obj:
  print((df[i].value_counts()))
  print()
# Out:
# Company Name
# Tata Consultancy Services         268
# Infosys                           168
# Amazon                            148
# Accenture                         146
# Cognizant Technology Solutions    139
#                                  ...
# Project42 Labs                      1
# Transfin.                           1
# ML Books International              1
# Infallible HR                       1
# Nextgen Innovation Labs             1
# Name: count, Length: 10952, dtype: int64
#
# Job Title
# Software Development Engineer          2206
# Android Developer                      1994
# Software Development Engineer (SDE)    1515
# Front End Developer                    1376
# Test Engineer                          1298
#                                        ...
# Full Stack Mobile Developer               1
# Mobile Team Lead                          1
# Senior Front-End Engineer                 1
# Xamarin Mobile Developer                  1
# ...

# %%
df[['Location', 'Salary']].groupby('Location').agg(['mean', 'median', 'max', 'count', 'std']).sort_values(by=('Salary', 'mean'), ascending=False)
# Out:
#                        Salary
#                          mean    median      max count            std
# Location
# Mumbai          743303.121805  636000.0  1700000   665  426042.659971
# Bangalore       595776.367288  500000.0  1700000  7667  398197.404332
# Pune            581475.843796  500000.0  1700000  2023  390957.007955
# Kolkata         566359.281437  500000.0  1700000   167  412251.023387
# Jaipur          566153.846154  490000.0  1400000    78  351826.221748
# Hyderabad       560851.345834  468000.0  1700000  4213  374532.611130
# New Delhi       560724.201295  500000.0  1700000  4014  372359.097721
# Chennai         518552.417508  400000.0  1700000  2376  355753.595060
# Kerala          514965.735849  490000.0  1300000   106  289644.717328
# Madhya Pradesh  505600.644295  492000.0  1700000   149  322472.274975

# %%
df[['Job Title', 'Salary']].groupby('Job Title').agg(['mean', 'median', 'max', 'count', 'std']).sort_values(by=('Salary', 'mean'), ascending=False)
# Out:
#                                                        Salary             \
#                                                          mean     median
# Job Title
# Lead Front End Engineer                             1700000.0  1700000.0
# Senior IOS Architect                                1700000.0  1700000.0
# Android Team Lead                                   1700000.0  1700000.0
# Development Expert-lead Software Engineer           1700000.0  1700000.0
# Senior Software Development Engineer I              1700000.0  1700000.0
# ...                                                       ...        ...
# Front-End Developer - Intern                          54000.0    48000.0
# IOS Engineer Contractor                               36000.0    36000.0
# Java Software Engineer Contractor                     31680.0    31680.0
# Senior Software Development Engineer In Test Co...    27456.0    27456.0
# Ios App Developer - Intern                            24000.0    24000.0
#
# ...

# %%
df[['Employment Status', 'Salary']].groupby('Employment Status').agg(['mean', 'median', 'max', 'count', 'std']).sort_values(by=('Salary', 'mean'), ascending=False)
# Out:
#                           Salary
#                             mean    median      max  count            std
# Employment Status
# Full Time          603928.124595  500000.0  1700000  18813  388554.399945
# Contractor         518950.848369  408000.0  1700000    521  343067.615003
# Intern             339560.730751  276000.0  1600000   2091  266920.408284
# Trainee            324303.030303  240000.0  1100000     33  241096.516572

# %%
df.groupby(['Location', 'Job Roles'])['Salary'].agg(['mean', 'median', 'max', 'count', 'std']).sort_values(by='mean', ascending=False)
# Out:
#                                   mean     median      max  count  \
# Location       Job Roles
# Chennai        Database   1.400000e+06  1400000.0  1400000      1
# Mumbai         Backend    1.100000e+06  1100000.0  1100000      1
#                IOS        9.000000e+05   900000.0   900000      1
#                SDE        7.425288e+05   624000.0  1700000    663
# Bangalore      Database   7.336959e+05   700000.0  1700000    759
# Hyderabad      SDE        7.158689e+05   600000.0  1700000   1318
# Bangalore      SDE        6.987259e+05   600000.0  1700000   1783
#                Backend    6.945045e+05   600000.0  1700000    413
#                IOS        6.913037e+05   600000.0  1700000    434
# Pune           SDE        6.904645e+05   600000.0  1700000    990
# Chennai        SDE        6.546052e+05   600000.0  1700000    634
# New Delhi      SDE        6.515580e+05   600000.0  1700000   1597
# Bangalore      Mobile     6.325455e+05   508000.0  1700000    220
# ...
